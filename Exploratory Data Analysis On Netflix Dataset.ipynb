# %% [markdown]
# # Step-by-Step Exploratory Data Analysis (EDA) using Python

# %%
Name = Khurram Shahin
Regd No 12112093
Roll no 03
sub Int 353

# %% [markdown]
# # Step 1: Import Python Libraries

# %% [markdown]
# # Import all libraries which are required for our analysis, such as Data Loading, Statistical analysis, Visualizations, Data Transformations, Merge and Joins, etc.

# %% [markdown]
# # Pandas and Numpy have been used for Data Manipulation and numerical Calculations

# %% [markdown]
# # Matplotlib and Seaborn have been used for Data visualizations

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# # Step 2: Reading Dataset

# %% [markdown]
# # Most of the data are available in a tabular format of CSV files. It is trendy and easy to access. Using the read_csv() function, data can be converted to a pandas DataFrame.

# %% [markdown]
# # The dataset contains information about movies and TV shows that are available on Netflix. In this dataset, we useed to identify trends in the entertainment industry, such as the rising popularity of streaming services or the increasing diversity of  content Offering

# %%
Data=pd.read_csv("Netflix Userbase.csv")

# %%
Data.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %% [markdown]
#  # tail() will display the last 5 observations of the dataset

# %%
Data.tail()
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#             Country  Age  Gender    Device Plan Duration
# 2495          Spain   28  Female  Smart TV       1 Month
# 2496          Spain   33  Female  Smart TV       1 Month
# 2497  United States   38    Male    Laptop       1 Month
# 2498         Canada   48  Female    Tablet       1 Month
# 2499  United States   35  Female  Smart TV       1 Month

# %% [markdown]
# # info() helps to understand the data type and information about data, including the number of records in each column, data having null or not null, Data type, the memory usage of the dataset

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %% [markdown]
# # Analyzing the Data
# Before we make any inferences, we listen to our data by examining all variables in the data.
#
# The main goal of data understanding is to gain general insights about the data, which covers the number of rows and columns, values in the data, datatypes, and Missing values in the dataset.
#
# shape – shape will display the number of observations(rows) and features(columns) in the dataset
#
# There are  2500 observations and 10 variables in our dataset
#
#
# head() will display the top 5 observations of the dataset

# %% [markdown]
# # Check for Duplication
#     nunique() based on several unique values in each column and the data description, we can identify the continuous and
#     categorical columns in the data. Duplicated data can be handled or removed based on further analysis

# %%
Data.nunique()
# Out:
# User ID              2500
# Subscription Type       3
# Monthly Revenue         6
# Join Date             300
# Last Payment Date      26
# Country                10
# Age                    26
# Gender                  2
# Device                  4
# Plan Duration           1
# dtype: int64

# %% [markdown]
# # Missing Values Calculation
# isnull() is widely been in all pre-processing steps to identify null values in the data
#
# In our example, data.isnull().sum() is used to get the number of missing records in each column

# %%
Data.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %% [markdown]
# # The below code helps to calculate the percentage of missing values in each column

# %%
(Data.isnull().sum()/(len(Data)))*100
# Out:
# User ID              0.0
# Subscription Type    0.0
# Monthly Revenue      0.0
# Join Date            0.0
# Last Payment Date    0.0
# Country              0.0
# Age                  0.0
# Gender               0.0
# Device               0.0
# Plan Duration        0.0
# dtype: float64

# %% [markdown]
# # The percentage of missing values for all the Columns Are 0 so there is no need Of Data reduction

# %% [markdown]
#  In our dataset, the column User Id have only ID values, assuming they don’t have any predictive power to
#  predict the dependent variable.

# %%
# Remove User Id. column from data
Data.drop("User ID",axis=1,inplace=True)
Data.head()
# Out:
#   Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0             Basic               10  15-01-22          10-06-23
# 1           Premium               15  05-09-21          22-06-23
# 2          Standard               12  28-02-23          27-06-23
# 3          Standard               12  10-07-22          26-06-23
# 4             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %% [markdown]
# Change The Column Name Monthly Revenue Subscription Type And Plan Duration¶

# %%
Data.rename(columns = {"Monthly Revenue":"MonthlyRevenue"}, inplace=True)

# %%
Data.rename(columns = {"Subscription Type":"SubscriptionType"}, inplace=True)

# %%
Data.rename(columns = {"Join Date":"joinDate"}, inplace=True)
Data.rename(columns = {"Last Payment Date":"LastPaymentDate"}, inplace=True)
Data.rename(columns = {"Plan Duration":"PlanDuration"}, inplace=True)

# %%
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue  joinDate LastPaymentDate         Country  \
# 0            Basic              10  15-01-22        10-06-23   United States
# 1          Premium              15  05-09-21        22-06-23          Canada
# 2         Standard              12  28-02-23        27-06-23  United Kingdom
# 3         Standard              12  10-07-22        26-06-23       Australia
# 4            Basic              10  01-05-23        28-06-23         Germany
#
#    Age  Gender      Device PlanDuration
# 0   28    Male  Smartphone      1 Month
# 1   35  Female      Tablet      1 Month
# 2   42    Male    Smart TV      1 Month
# 3   51  Female      Laptop      1 Month
# 4   33    Male  Smartphone      1 Month

# %% [markdown]
# # Step 4: Feature Engineering

# %% [markdown]
# Feature engineering refers to the process of using domain knowledge to select and transform the most relevant variables from raw data whencreating a predictive model using machine learning or statistical modeling. The main goal of Feature engineering is to createmeaningful data from raw data.

# %% [markdown]
# # Calculate the duration of the subscription (e.g., "Subscription Duration" = "Last Payment Date" - "Join Date").

# %%
# Convert date columns to datetime objects
Data['joinDate'] = pd.to_datetime(Data['joinDate'], format='%d-%m-%y')
Data['LastPaymentDate'] = pd.to_datetime(Data['LastPaymentDate'], format='%d-%m-%y')

# %%
# Calculate the subscription duration
Data['Subscription Duration'] = Data['LastPaymentDate'] - Data['joinDate']

# %%
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate         Country  \
# 0            Basic              10 2022-01-15      2023-06-10   United States
# 1          Premium              15 2021-09-05      2023-06-22          Canada
# 2         Standard              12 2023-02-28      2023-06-27  United Kingdom
# 3         Standard              12 2022-07-10      2023-06-26       Australia
# 4            Basic              10 2023-05-01      2023-06-28         Germany
#
#    Age  Gender      Device PlanDuration Subscription Duration
# 0   28    Male  Smartphone      1 Month              511 days
# 1   35  Female      Tablet      1 Month              655 days
# 2   42    Male    Smart TV      1 Month              119 days
# 3   51  Female      Laptop      1 Month              351 days
# 4   33    Male  Smartphone      1 Month               58 days

# %% [markdown]
# Extract year, month, and day from the "Join Date" and "Last Payment Date" columns.
# These features could help in analyze trends over time

# %%
# Extract year, month, and day
Data['joinYear'] = Data['joinDate'].dt.year
Data['Join Month'] = Data['joinDate'].dt.month
Data['Join Day'] = Data['joinDate'].dt.day

Data['LastPaymentYear'] = Data['LastPaymentDate'].dt.year
Data['Last Payment Month'] = Data['LastPaymentDate'].dt.month
Data['Last Payment Day'] = Data['LastPaymentDate'].dt.day

# Print the DataFrame with extracted date components
Data
# Out:
#      SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate  \
# 0               Basic              10 2022-01-15      2023-06-10
# 1             Premium              15 2021-09-05      2023-06-22
# 2            Standard              12 2023-02-28      2023-06-27
# 3            Standard              12 2022-07-10      2023-06-26
# 4               Basic              10 2023-05-01      2023-06-28
# ...               ...             ...        ...             ...
# 2495          Premium              14 2022-07-25      2023-07-12
# 2496            Basic              15 2022-08-04      2023-07-14
# 2497         Standard              12 2022-08-09      2023-07-15
# 2498         Standard              13 2022-08-12      2023-07-12
# 2499            Basic              15 2022-08-13      2023-07-12
#
#              Country  Age  Gender      Device PlanDuration  \
# 0      United States   28    Male  Smartphone      1 Month
# 1             Canada   35  Female      Tablet      1 Month
# 2     United Kingdom   42    Male    Smart TV      1 Month
# 3          Australia   51  Female      Laptop      1 Month
# 4            Germany   33    Male  Smartphone      1 Month
# ...              ...  ...     ...         ...          ...
# 2495           Spain   28  Female    Smart TV      1 Month
# 2496           Spain   33  Female    Smart TV      1 Month
# 2497   United States   38    Male      Laptop      1 Month
# 2498          Canada   48  Female      Tablet      1 Month
# 2499   United States   35  Female    Smart TV      1 Month
#
#      Subscription Duration  joinYear  Join Month  Join Day  LastPaymentYear  \
# 0                 511 days      2022           1        15             2023
# 1                 655 days      2021           9         5             2023
# 2                 119 days      2023           2        28             2023
# 3                 351 days      2022           7        10             2023
# 4                  58 days      2023           5         1             2023
# ...                    ...       ...         ...       ...              ...
# 2495              352 days      2022           7        25             2023
# 2496              344 days      2022           8         4             2023
# 2497              340 days      2022           8         9             2023
# 2498              334 days      2022           8        12             2023
# 2499              333 days      2022           8        13             2023
#
#       Last Payment Month  Last Payment Day
# 0                      6                10
# 1                      6                22
# 2                      6                27
# 3                      6                26
# 4                      6                28
# ...                  ...               ...
# 2495                   7                12
# 2496                   7                14
# 2497                   7                15
# 2498                   7                12
# 2499                   7                12
#
# [2500 rows x 16 columns]

# %%
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate         Country  \
# 0            Basic              10 2022-01-15      2023-06-10   United States
# 1          Premium              15 2021-09-05      2023-06-22          Canada
# 2         Standard              12 2023-02-28      2023-06-27  United Kingdom
# 3         Standard              12 2022-07-10      2023-06-26       Australia
# 4            Basic              10 2023-05-01      2023-06-28         Germany
#
#    Age  Gender      Device PlanDuration Subscription Duration  joinYear  \
# 0   28    Male  Smartphone      1 Month              511 days      2022
# 1   35  Female      Tablet      1 Month              655 days      2021
# 2   42    Male    Smart TV      1 Month              119 days      2023
# 3   51  Female      Laptop      1 Month              351 days      2022
# 4   33    Male  Smartphone      1 Month               58 days      2023
#
#    Join Month  Join Day  LastPaymentYear  Last Payment Month  Last Payment Day
# 0           1        15             2023                   6                10
# 1           9         5             2023                   6                22
# 2           2        28             2023                   6                27
# 3           7        10             2023                   6                26
# 4           5         1             2023                   6                28

# %% [markdown]
#  # Encode the "Gender" column as binary (0 for Male, 1 for Female).

# %%
Data['Gender'] = Data['Gender'].apply(lambda x: 0 if x == 'Male' else 1)
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate         Country  \
# 0            Basic              10 2022-01-15      2023-06-10   United States
# 1          Premium              15 2021-09-05      2023-06-22          Canada
# 2         Standard              12 2023-02-28      2023-06-27  United Kingdom
# 3         Standard              12 2022-07-10      2023-06-26       Australia
# 4            Basic              10 2023-05-01      2023-06-28         Germany
#
#    Age  Gender      Device PlanDuration Subscription Duration  joinYear  \
# 0   28       0  Smartphone      1 Month              511 days      2022
# 1   35       1      Tablet      1 Month              655 days      2021
# 2   42       0    Smart TV      1 Month              119 days      2023
# 3   51       1      Laptop      1 Month              351 days      2022
# 4   33       0  Smartphone      1 Month               58 days      2023
#
#    Join Month  Join Day  LastPaymentYear  Last Payment Month  Last Payment Day
# 0           1        15             2023                   6                10
# 1           9         5             2023                   6                22
# 2           2        28             2023                   6                27
# 3           7        10             2023                   6                26
# 4           5         1             2023                   6                28

# %% [markdown]
# # Group ages into bins or categories to create an "Age Group" feature.

# %% [markdown]
# Encode the "Gender" column as binary (0 for Male, 1 for Female).

# %%
# Define age group bins and labels
age_bins = [0, 30, 50, 80,]  # Define age bins
age_labels = ['Young', 'Middle-aged', 'Elderly']  # Define corresponding labels

# Create the "Age Group" feature
Data['Age Group'] = pd.cut(Data['Age'], bins=age_bins, labels=age_labels, right=False)

# Print the DataFrame with the "Age Group" feature
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate         Country  \
# 0            Basic              10 2022-01-15      2023-06-10   United States
# 1          Premium              15 2021-09-05      2023-06-22          Canada
# 2         Standard              12 2023-02-28      2023-06-27  United Kingdom
# 3         Standard              12 2022-07-10      2023-06-26       Australia
# 4            Basic              10 2023-05-01      2023-06-28         Germany
#
#    Age  Gender      Device PlanDuration Subscription Duration  joinYear  \
# 0   28       0  Smartphone      1 Month              511 days      2022
# 1   35       1      Tablet      1 Month              655 days      2021
# 2   42       0    Smart TV      1 Month              119 days      2023
# 3   51       1      Laptop      1 Month              351 days      2022
# 4   33       0  Smartphone      1 Month               58 days      2023
#
#    Join Month  Join Day  LastPaymentYear  Last Payment Month  \
# 0           1        15             2023                   6
# 1           9         5             2023                   6
# 2           2        28             2023                   6
# 3           7        10             2023                   6
# 4           5         1             2023                   6
#
#    Last Payment Day    Age Group
# 0                10        Young
# 1                22  Middle-aged
# 2                27  Middle-aged
# 3                26      Elderly
# 4                28  Middle-aged

# %%
Data['Gender'] = Data['Gender'].apply(lambda x: 0 if x == 'Male' else 1)
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate         Country  \
# 0            Basic              10 2022-01-15      2023-06-10   United States
# 1          Premium              15 2021-09-05      2023-06-22          Canada
# 2         Standard              12 2023-02-28      2023-06-27  United Kingdom
# 3         Standard              12 2022-07-10      2023-06-26       Australia
# 4            Basic              10 2023-05-01      2023-06-28         Germany
#
#    Age  Gender      Device PlanDuration Subscription Duration  joinYear  \
# 0   28       1  Smartphone      1 Month              511 days      2022
# 1   35       1      Tablet      1 Month              655 days      2021
# 2   42       1    Smart TV      1 Month              119 days      2023
# 3   51       1      Laptop      1 Month              351 days      2022
# 4   33       1  Smartphone      1 Month               58 days      2023
#
#    Join Month  Join Day  LastPaymentYear  Last Payment Month  \
# 0           1        15             2023                   6
# 1           9         5             2023                   6
# 2           2        28             2023                   6
# 3           7        10             2023                   6
# 4           5         1             2023                   6
#
#    Last Payment Day    Age Group
# 0                10        Young
# 1                22  Middle-aged
# 2                27  Middle-aged
# 3                26      Elderly
# 4                28  Middle-aged

# %% [markdown]
# #  Data Cleaning/Wrangling

# %% [markdown]
#   It Might Happen That Some names of the variables are not relevant and not easy to understand. Some data may have data entry     errors, and some variables may need data type conversion

# %% [markdown]
# Lets Check For Unique Data inside Column After Feature Engineering Of Data

# %%
print(Data.Country.unique())
print(Data.SubscriptionType.unique())
# Out:
# ['United States' 'Canada' 'United Kingdom' 'Australia' 'Germany' 'France'
#  'Brazil' 'Mexico' 'Spain' 'Italy']
# ['Basic' 'Premium' 'Standard']

# %% [markdown]
#  Since It does Not Contain Any unique Data SO  We need to fix any  issue in the data

# %% [markdown]
#  # As  We have done the fundamental data analysis, Featuring, and data clean-       up. Our Data is ready to perform EDA ,                                                                                                                                                                                                                                      Let’s move to the EDA process

# %% [markdown]
# describe()– Provide a statistics summary of data belonging to numerical datatype such as int, float

# %%
Data.describe()
# Out:
#        MonthlyRevenue                    joinDate             LastPaymentDate  \
# count     2500.000000                        2500                        2500
# mean        12.508400  2022-08-28 18:02:52.800000  2023-07-03 08:54:31.680000
# min         10.000000         2021-09-05 00:00:00         2023-06-10 00:00:00
# 25%         11.000000         2022-07-15 00:00:00         2023-06-29 00:00:00
# 50%         12.000000         2022-08-31 00:00:00         2023-07-03 00:00:00
# 75%         14.000000         2022-10-17 00:00:00         2023-07-08 00:00:00
# max         15.000000         2023-06-14 00:00:00         2023-07-15 00:00:00
# std          1.686851                         NaN                         NaN
#
#                Age  Gender       Subscription Duration     joinYear  \
# count  2500.000000  2500.0                        2500  2500.000000
# mean     38.795600     1.0    308 days 14:51:38.880000  2022.009600
# min      26.000000     1.0             8 days 00:00:00  2021.000000
# 25%      32.000000     1.0           261 days 00:00:00  2022.000000
# 50%      39.000000     1.0           307 days 00:00:00  2022.000000
# 75%      45.000000     1.0           356 days 00:00:00  2022.000000
# max      51.000000     1.0           655 days 00:00:00  2023.000000
# std       7.171778     0.0  63 days 02:06:58.055345063     0.143931
#
#         Join Month     Join Day  LastPaymentYear  Last Payment Month  \
# count  2500.000000  2500.000000           2500.0         2500.000000
# mean      8.321600    15.392800           2023.0            6.653600
# min       1.000000     1.000000           2023.0            6.000000
# 25%       7.000000     7.000000           2023.0            6.000000
# 50%       8.000000    15.000000           2023.0            7.000000
# 75%      10.000000    23.000000           2023.0            7.000000
# max      12.000000    31.000000           2023.0            7.000000
# std       1.966449     8.990998              0.0            0.475918
#
#        Last Payment Day
# count       2500.000000
# mean          13.763200
# min            1.000000
# 25%            5.000000
# 50%           10.000000
# 75%           26.000000
# max           30.000000
# std           10.327952

# %% [markdown]
# decribe(include=’all’) provides a statistics summary of all data, include object, category etc

# %%
Data.describe(include='all')
# Out:
#        SubscriptionType  MonthlyRevenue                    joinDate  \
# count              2500     2500.000000                        2500
# unique                3             NaN                         NaN
# top               Basic             NaN                         NaN
# freq                999             NaN                         NaN
# mean                NaN       12.508400  2022-08-28 18:02:52.800000
# min                 NaN       10.000000         2021-09-05 00:00:00
# 25%                 NaN       11.000000         2022-07-15 00:00:00
# 50%                 NaN       12.000000         2022-08-31 00:00:00
# 75%                 NaN       14.000000         2022-10-17 00:00:00
# max                 NaN       15.000000         2023-06-14 00:00:00
# std                 NaN        1.686851                         NaN
#
#                    LastPaymentDate        Country          Age  Gender  \
# count                         2500           2500  2500.000000  2500.0
# unique                         NaN             10          NaN     NaN
# top                            NaN  United States          NaN     NaN
# freq                           NaN            451          NaN     NaN
# mean    2023-07-03 08:54:31.680000            NaN    38.795600     1.0
# min            2023-06-10 00:00:00            NaN    26.000000     1.0
# 25%            2023-06-29 00:00:00            NaN    32.000000     1.0
# 50%            2023-07-03 00:00:00            NaN    39.000000     1.0
# 75%            2023-07-08 00:00:00            NaN    45.000000     1.0
# max            2023-07-15 00:00:00            NaN    51.000000     1.0
# std                            NaN            NaN     7.171778     0.0
#
#         Device PlanDuration       Subscription Duration     joinYear  \
# count     2500         2500                        2500  2500.000000
# unique       4            1                         NaN          NaN
# top     Laptop      1 Month                         NaN          NaN
# freq       636         2500                         NaN          NaN
# mean       NaN          NaN    308 days 14:51:38.880000  2022.009600
# min        NaN          NaN             8 days 00:00:00  2021.000000
# 25%        NaN          NaN           261 days 00:00:00  2022.000000
# 50%        NaN          NaN           307 days 00:00:00  2022.000000
# 75%        NaN          NaN           356 days 00:00:00  2022.000000
# max        NaN          NaN           655 days 00:00:00  2023.000000
# std        NaN          NaN  63 days 02:06:58.055345063     0.143931
#
#          Join Month     Join Day  LastPaymentYear  Last Payment Month  \
# count   2500.000000  2500.000000           2500.0         2500.000000
# unique          NaN          NaN              NaN                 NaN
# top             NaN          NaN              NaN                 NaN
# freq            NaN          NaN              NaN                 NaN
# mean       8.321600    15.392800           2023.0            6.653600
# min        1.000000     1.000000           2023.0            6.000000
# 25%        7.000000     7.000000           2023.0            6.000000
# 50%        8.000000    15.000000           2023.0            7.000000
# 75%       10.000000    23.000000           2023.0            7.000000
# max       12.000000    31.000000           2023.0            7.000000
# std        1.966449     8.990998              0.0            0.475918
#
#         Last Payment Day    Age Group
# count        2500.000000         2500
# unique               NaN            3
# top                  NaN  Middle-aged
# freq                 NaN         2016
# mean           13.763200          NaN
# min             1.000000          NaN
# 25%             5.000000          NaN
# 50%            10.000000          NaN
# 75%            26.000000          NaN
# max            30.000000          NaN
# std            10.327952          NaN

# %% [markdown]
# Before we do EDA, lets separate Numerical and categorical variables for easy analysis

# %%
cat_cols=Data.select_dtypes(include=['object']).columns
num_cols = Data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['SubscriptionType', 'Country', 'Device', 'PlanDuration'], dtype='object')
# Numerical Variables:
# ['MonthlyRevenue', 'Age', 'Gender', 'Subscription Duration', 'joinYear', 'Join Month', 'Join Day', 'LastPaymentYear', 'Last Payment Month', 'Last Payment Day']

# %% [markdown]
# # UnivariatAnalysis

# %% [markdown]
# Univariate analysis can be done for both Categorical and Numerical variables.
#
# Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
#
# Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.

# %%
# First I will Do Univarite Analysis on Categorical Data

# %%
 #Univariate analysis of Subscription Type
subscription_type_counts = Data['SubscriptionType'].value_counts()
subscription_type_percentage = Data['SubscriptionType'].value_counts(normalize=True) * 100

# %%
# Bar chart
plt.figure(figsize=(8, 6))
subscription_type_counts.plot(kind='bar')
plt.title("Distribution of Subscription Types")
plt.xlabel("Subscription Type")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Display the count and percentage distribution
print("Subscription Type Counts:")
print(subscription_type_counts)
# Out:
# Subscription Type Counts:
# SubscriptionType
# Basic       999
# Standard    768
# Premium     733
# Name: count, dtype: int64

# %%
print("\nSubscription Type Percentage Distribution:")
print(subscription_type_percentage)
# Out:
# Subscription Type Percentage Distribution:
# SubscriptionType
# Basic       39.96
# Standard    30.72
# Premium     29.32
# Name: proportion, dtype: float64

# %%
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(subscription_type_counts, labels=subscription_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Subscription Type Distribution")

# Display the pie chart
plt.show()

# %%
# Lets do Univariate Analysis on Country Column

# %%
 #Count the frequency of customers from each country
country_counts = Data['Country'].value_counts()

# Calculate the percentage distribution of customers from each country
country_percentage = (country_counts / country_counts.sum()) * 100

# %%
# Create a bar chart for the country distribution
plt.figure(figsize=(12, 6))
country_counts.plot(kind='bar')
plt.title("Distribution of Customers by Country")
plt.xlabel("Country")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# %%
# Display the count and percentage distribution
print("Country Counts:")
print(country_counts)

print("\nCountry Percentage Distribution:")
print(country_percentage)
# Out:
# Country Counts:
# Country
# United States     451
# Spain             451
# Canada            317
# United Kingdom    183
# Australia         183
# Germany           183
# France            183
# Brazil            183
# Mexico            183
# Italy             183
# Name: count, dtype: int64
#
# Country Percentage Distribution:
# Country
# United States     18.04
# Spain             18.04
# Canada            12.68
# United Kingdom     7.32
# Australia          7.32
# Germany            7.32
# France             7.32
# Brazil             7.32
# Mexico             7.32
# Italy              7.32
# Name: count, dtype: float64

# %%
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(country_percentage, labels=country_percentage.index, autopct='%1.1f%%',startangle=140)
plt.title("Country Percentage Distribution")

# Display the pie chart
plt.show()

# %%
# Univariate Analysis on Gender Column

# %%
# Count the frequency of each gender (0 for Male, 1 for Female)
gender_counts = Data['Gender'].value_counts()

# Calculate the percentage distribution of genders
gender_percentage = (gender_counts / gender_counts.sum()) * 100

# Create a bar chart for the gender distribution
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar')
plt.title("Distribution of Genders")
plt.xlabel("Gender (0: Male, 1: Female)")
plt.ylabel("Count")
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# Display the count and percentage distribution
print("Gender Counts:")
print(gender_counts)

print("\nGender Percentage Distribution:")
print(gender_percentage)
# Out:
# Gender Counts:
# Gender
# 1    2500
# Name: count, dtype: int64
#
# Gender Percentage Distribution:
# Gender
# 1    100.0
# Name: count, dtype: float64

# %% [markdown]
# #  The dataset exclusively contains data for customers with a "Male" gender. This indicates that the analysis,in this case, is focused solely on male customers, and any insights or conclusions derived from the dataset will pertain to this specific demographic group. It's essential to consider the specific characteristics and behaviorsof male customers when interpreting the results and making decisions related to your business or research objectives.

# %%
# univariate Analysis on Device

# %%
# Count the frequency of each type of device
device_counts = Data['Device'].value_counts()

# Calculate the percentage distribution of different devices
device_percentage = (device_counts / device_counts.sum()) * 100

# Create a bar chart for the device distribution
plt.figure(figsize=(10, 6))
device_counts.plot(kind='bar')
plt.title("Distribution of Devices Used by Customers")
plt.xlabel("Device Type")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# Display the count and percentage distribution
print("Device Counts:")
print(device_counts)

print("\nDevice Percentage Distribution:")
print(device_percentage)
# Out:
# Device Counts:
# Device
# Laptop        636
# Tablet        633
# Smartphone    621
# Smart TV      610
# Name: count, dtype: int64
#
# Device Percentage Distribution:
# Device
# Laptop        25.44
# Tablet        25.32
# Smartphone    24.84
# Smart TV      24.40
# Name: count, dtype: float64

# %%
# Create a pie chart
plt.figure(figsize=(8,8))
plt.pie(device_percentage , labels=device_percentage .index, autopct='%11.1f%%',startangle=140)
plt.title("Device Percentage Distribution")

# Display the pie chart
plt.show()

# %%
# univariate Analysis on PlanDuration

# %%
# Count the frequency of Plan Dutation
plan_Duration = Data['PlanDuration'].value_counts()

# Calculate the percentage distribution of different devices
plan_DurationPercentage = (plan_Duration / plan_Duration.sum()) * 100

# Create a bar chart for the device distribution
plt.figure(figsize=(10, 6))
plan_Duration.plot(kind='bar')
plt.title("Distribution of Plans Used by Customers")
plt.xlabel("Plan Duration")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# Display the count and percentage distribution
print("Plan Duration")
print(plan_Duration)

print("\nPlan Percentage Distribution:")
print(plan_DurationPercentage)
# Out:
# Plan Duration
# PlanDuration
# 1 Month    2500
# Name: count, dtype: int64
#
# Plan Percentage Distribution:
# PlanDuration
# 1 Month    100.0
# Name: count, dtype: float64

# %%
# univariate Analysis on Age Group

# %%
# Count the frequency of Different Age Group
Age_Group = Data['Age Group'].value_counts()

# Calculate the percentage distribution of different devices
Age_Group_Percentage= (Age_Group / Age_Group.sum()) * 100

# Create a bar chart for the device distribution
plt.figure(figsize=(10, 6))
Age_Group.plot(kind='bar')
plt.title("Distribution of Customers Of Different Age Group")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# Display the count and percentage distribution
print("Age_Group")
print(Age_Group)

print("\nAge_Group_Percentage")
print(Age_Group_Percentage)
# Out:
# Age_Group
# Age Group
# Middle-aged    2016
# Young           307
# Elderly         177
# Name: count, dtype: int64
#
# Age_Group_Percentage
# Age Group
# Middle-aged    80.64
# Young          12.28
# Elderly         7.08
# Name: count, dtype: float64

# %%
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate         Country  \
# 0            Basic              10 2022-01-15      2023-06-10   United States
# 1          Premium              15 2021-09-05      2023-06-22          Canada
# 2         Standard              12 2023-02-28      2023-06-27  United Kingdom
# 3         Standard              12 2022-07-10      2023-06-26       Australia
# 4            Basic              10 2023-05-01      2023-06-28         Germany
#
#    Age  Gender      Device PlanDuration Subscription Duration  joinYear  \
# 0   28       1  Smartphone      1 Month              511 days      2022
# 1   35       1      Tablet      1 Month              655 days      2021
# 2   42       1    Smart TV      1 Month              119 days      2023
# 3   51       1      Laptop      1 Month              351 days      2022
# 4   33       1  Smartphone      1 Month               58 days      2023
#
#    Join Month  Join Day  LastPaymentYear  Last Payment Month  \
# 0           1        15             2023                   6
# 1           9         5             2023                   6
# 2           2        28             2023                   6
# 3           7        10             2023                   6
# 4           5         1             2023                   6
#
#    Last Payment Day    Age Group
# 0                10        Young
# 1                22  Middle-aged
# 2                27  Middle-aged
# 3                26      Elderly
# 4                28  Middle-aged

# %%
# Create a pie chart
plt.figure(figsize=(8,8))
plt.pie(Age_Group , labels=Age_Group_Percentage .index, autopct='%11.1f%%',startangle=140)
plt.title("Age Group Percentage Distribution")

# Display the pie chart
plt.show()

# %%
# For The Catogorical Univariate Analysis We Can Have Below Observations

# %% [markdown]
# [:]40% of the user have Basic Subscription Type
# [:]UnitedStates And Spain Has Highest Customer Frequency With 18% in Each Country
# [:]United Kingdom,Australia,Germany,France,Brazil,Mexico, Italy have same Customer
#  Frequency With 7.3%
# [:]There Are Only Male Viewer In This Dataset
# [:]25.4% of user use laptop. which shows that most of the customer use laptop for Streaming
# [:]80% of users Are Middle-aged Group:This Shows The Target Audiences Are Middle
#     m

# %% [markdown]
# # Lets Do univariate Analysis for Univariate Numerical Data

# %%
cat_cols=Data.select_dtypes(include=['object']).columns
num_cols = Data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['SubscriptionType', 'Country', 'Device', 'PlanDuration'], dtype='object')
# Numerical Variables:
# ['MonthlyRevenue', 'Age', 'Gender', 'Subscription Duration', 'joinYear', 'Join Month', 'Join Day', 'LastPaymentYear', 'Last Payment Month', 'Last Payment Day']

# %%
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate         Country  \
# 0            Basic              10 2022-01-15      2023-06-10   United States
# 1          Premium              15 2021-09-05      2023-06-22          Canada
# 2         Standard              12 2023-02-28      2023-06-27  United Kingdom
# 3         Standard              12 2022-07-10      2023-06-26       Australia
# 4            Basic              10 2023-05-01      2023-06-28         Germany
#
#    Age  Gender      Device PlanDuration Subscription Duration  joinYear  \
# 0   28       1  Smartphone      1 Month              511 days      2022
# 1   35       1      Tablet      1 Month              655 days      2021
# 2   42       1    Smart TV      1 Month              119 days      2023
# 3   51       1      Laptop      1 Month              351 days      2022
# 4   33       1  Smartphone      1 Month               58 days      2023
#
#    Join Month  Join Day  LastPaymentYear  Last Payment Month  \
# 0           1        15             2023                   6
# 1           9         5             2023                   6
# 2           2        28             2023                   6
# 3           7        10             2023                   6
# 4           5         1             2023                   6
#
#    Last Payment Day    Age Group
# 0                10        Young
# 1                22  Middle-aged
# 2                27  Middle-aged
# 3                26      Elderly
# 4                28  Middle-aged

# %%
# Numerical Analysis  based On Monthly Revenue

# %% [markdown]
# Calculate summary statistics for each numerical column:

# %%
for column in num_cols:
    print(column, ':')
    print(Data[column].describe())
# Out:
# MonthlyRevenue :
# count    2500.000000
# mean       12.508400
# std         1.686851
# min        10.000000
# 25%        11.000000
# 50%        12.000000
# 75%        14.000000
# max        15.000000
# Name: MonthlyRevenue, dtype: float64
# Age :
# count    2500.000000
# mean       38.795600
# std         7.171778
# min        26.000000
# 25%        32.000000
# 50%        39.000000
# 75%        45.000000
# max        51.000000
# Name: Age, dtype: float64
# Gender :
# count    2500.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: Gender, dtype: float64
# Subscription Duration :
# count                          2500
# mean       308 days 14:51:38.880000
# std      63 days 02:06:58.055345063
# min                 8 days 00:00:00
# 25%               261 days 00:00:00
# 50%               307 days 00:00:00
# 75%               356 days 00:00:00
# max               655 days 00:00:00
# Name: Subscription Duration, dtype: object
# joinYear :
# count    2500.000000
# mean     2022.009600
# std         0.143931
# min      2021.000000
# 25%      2022.000000
# 50%      2022.000000
# 75%      2022.000000
# max      2023.000000
# Name: joinYear, dtype: float64
# Join Month :
# count    2500.000000
# mean        8.321600
# std         1.966449
# min         1.000000
# 25%         7.000000
# 50%         8.000000
# 75%        10.000000
# max        12.000000
# Name: Join Month, dtype: float64
# Join Day :
# count    2500.000000
# mean       15.392800
# std         8.990998
# min         1.000000
# 25%         7.000000
# 50%        15.000000
# 75%        23.000000
# max        31.000000
# Name: Join Day, dtype: float64
# LastPaymentYear :
# count    2500.0
# mean     2023.0
# std         0.0
# min      2023.0
# 25%      2023.0
# 50%      2023.0
# 75%      2023.0
# max      2023.0
# Name: LastPaymentYear, dtype: float64
# Last Payment Month :
# count    2500.000000
# mean        6.653600
# std         0.475918
# min         6.000000
# 25%         6.000000
# 50%         7.000000
# 75%         7.000000
# max         7.000000
# Name: Last Payment Month, dtype: float64
# Last Payment Day :
# count    2500.000000
# mean       13.763200
# std        10.327952
# min         1.000000
# 25%         5.000000
# 50%        10.000000
# 75%        26.000000
# max        30.000000
# Name: Last Payment Day, dtype: float64

# %%
# Frequency of Monthly Revenue

# %%
plt.hist(Data['MonthlyRevenue'])
plt.xlabel('Monthly Revenue')
plt.ylabel('Frequency')
plt.title('Distribution of Monthly Revenue')
plt.show()

# %%
sns.catplot(x = "MonthlyRevenue" , data =Data  , kind = "count" )
# Out:
# C:\Users\khurr\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.hist(Data['Age'])
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.title('Distribution of Monthly Revenue BY age group')
plt.show()

# %%
import pandas as pd

Data['Subscription Duration'] = pd.to_numeric(Data['Subscription Duration'])

# %%
plt.hist(Data['Subscription Duration'])
plt.xlabel('Subscription Duration')
plt.ylabel('Frequency')
plt.title('Distribution of Monthly Revenue')
plt.show()

# %%
# Get the Subscription Duration column
subscription_duration = Data['Subscription Duration']

# Get the unique values of the Subscription Duration column
unique_subscription_duration = subscription_duration.unique()

# Get the counts of the unique values of the Subscription Duration column
counts = subscription_duration.value_counts()

# Create a pie chart of the Subscription Duration column
plt.pie(counts, labels=unique_subscription_duration, autopct="%1.1f%%")
plt.title("Pie Chart of Subscription Duration")
plt.show()

# %%
# Since Subscription Duration  Contains Lots Of numerical Value So we Need To categorise In Terms Of Months

# %%
# Define age group bins and labels
Subscription_bins = [0, 30, 400, 900,]  # Define age bins
Subscription_labels = ['Low: Less than 3 months',
'Medium: 3 to 6 months',
'High: 6 months or more']  # Define corresponding labels

# Create the "Age Group" feature
Data['Subscription Duration'] = pd.cut(Data['Age'], bins=Subscription_bins, labels=Subscription_labels, right=False)

# Print the DataFrame with the "Age Group" feature
Data.head()
# Out:
#   SubscriptionType  MonthlyRevenue   joinDate LastPaymentDate         Country  \
# 0            Basic              10 2022-01-15      2023-06-10   United States
# 1          Premium              15 2021-09-05      2023-06-22          Canada
# 2         Standard              12 2023-02-28      2023-06-27  United Kingdom
# 3         Standard              12 2022-07-10      2023-06-26       Australia
# 4            Basic              10 2023-05-01      2023-06-28         Germany
#
#    Age  Gender      Device PlanDuration    Subscription Duration  joinYear  \
# 0   28       1  Smartphone      1 Month  Low: Less than 3 months      2022
# 1   35       1      Tablet      1 Month    Medium: 3 to 6 months      2021
# 2   42       1    Smart TV      1 Month    Medium: 3 to 6 months      2023
# 3   51       1      Laptop      1 Month    Medium: 3 to 6 months      2022
# 4   33       1  Smartphone      1 Month    Medium: 3 to 6 months      2023
#
#    Join Month  Join Day  LastPaymentYear  Last Payment Month  \
# 0           1        15             2023                   6
# 1           9         5             2023                   6
# 2           2        28             2023                   6
# 3           7        10             2023                   6
# 4           5         1             2023                   6
#
#    Last Payment Day    Age Group
# 0                10        Young
# 1                22  Middle-aged
# 2                27  Middle-aged
# 3                26      Elderly
# 4                28  Middle-aged

# %%
# Count the frequency of Different Age Group
Subs_Dur = Data['Subscription Duration'].value_counts()

# Calculate the percentage distribution of different devices
Subs_Dur_Percentage= (Subs_Dur / Subs_Dur.sum()) * 100

# Create a bar chart for the device distribution
plt.figure(figsize=(10, 6))
Subs_Dur.plot(kind='bar')
plt.title("Distribution of Customers Of Different Subscription Duration")
plt.xlabel("Subscription Duration")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# Display the count and percentage distribution
print("Subscription Duration")
print(Subs_Dur)

print("\nAge_Group_Percentage")
print(Subs_Dur_Percentage)
# Out:
# Subscription Duration
# Subscription Duration
# Medium: 3 to 6 months      2193
# Low: Less than 3 months     307
# High: 6 months or more        0
# Name: count, dtype: int64
#
# Age_Group_Percentage
# Subscription Duration
# Medium: 3 to 6 months      87.72
# Low: Less than 3 months    12.28
# High: 6 months or more      0.00
# Name: count, dtype: float64

# %%
# Create a pie chart of the Subscription Duration column
plt.pie(Subs_Dur_Percentage, labels=Subscription_labels , autopct="%1.1f%%")
plt.title("Pie Chart of Subscription Duration")
plt.show()

# %% [markdown]
# Pairplot for numerical variables

# %%
sns.pairplot(Data, hue='SubscriptionType', diag_kind='kde')
plt.suptitle('Pairplot of Numerical Variables', y=1.02)
plt.show()
# Out:
# C:\Users\khurr\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
#  EDA Bivariate Analysis
# Now, let’s move ahead with bivariate analysis. Bivariate Analysis helps to understand how variables are related to each other and the relationship between dependent and independent variables
# present in the dataset.

# %%
# Let's assume you want to analyze the relationship between 'SubscriptionType' and 'MonthlyRevenue'

# 1. Scatter plot
sns.scatterplot(data=Data, x='SubscriptionType', y='MonthlyRevenue')
plt.title('Scatter Plot of Monthly Revenue by Subscription Type')
plt.xticks(rotation=45)
plt.show()

# %%
# 2. Box plot
sns.boxplot(data=Data, x='SubscriptionType', y='MonthlyRevenue')
plt.title('Box Plot of Monthly Revenue by Subscription Type')
plt.xticks(rotation=45)
plt.show()

# %%
 
revenue_by_subscription = Data.groupby('SubscriptionType')['MonthlyRevenue'].sum()

# Extract labels and values
labels = revenue_by_subscription.index
values = revenue_by_subscription.values

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Monthly Revenue by Subscription Type')

# Display the pie chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Basic Gives The Highest Monthly Revenue

# %%
# Relation Between Monthly Revenue And Age

# %%
# 5. Correlation matrix (for numerical variables)
numerical_columns = ['MonthlyRevenue', 'Age']
correlation_matrix = Data[numerical_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Correlation Coefficient:
# Calculate the correlation coefficient (e.g., Pearson correlation) between 'Age' and 'MonthlyRevenue' to measure the strength and
# direction of their relationship.

# %%
correlation_coefficient = Data['Age'].corr(Data['MonthlyRevenue'])
print(f'Correlation Coefficient (Age vs. MonthlyRevenue): {correlation_coefficient}')
# Out:
# Correlation Coefficient (Age vs. MonthlyRevenue): -0.02114326407144743

# %% [markdown]
# This value indicates a very weak negative correlation between Age And Monthly Revenue

# %%
# Select numerical columns
numerical_columns = ['MonthlyRevenue', 'Age']

# Create a correlation matrix
correlation_matrix = Data[numerical_columns].corr()

# Generate a heatmap with annotations
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Set the plot title
plt.title('Correlation Matrix for MonthlyRevenue and Age')

# Display the heatmap
plt.show()

# %%
#  Relationship between 'SubscriptionType' and 'Country'

# %% [markdown]
# # Frequency Table:
# Create a frequency table or a cross-tabulation to count the occurrences of each combination of 'SubscriptionType'
#  and 'Country'. This will give you an initial overview of the distribution

# %%
# Create a frequency table
frequency_table = pd.crosstab(Data['SubscriptionType'], Data['Country'])
print(frequency_table)
# Out:
# Country           Australia  Brazil  Canada  France  Germany  Italy  Mexico  \
# SubscriptionType
# Basic                    31     146     145      36      149    176       4
# Premium                 101      33      88     147        3      4       0
# Standard                 51       4      84       0       31      3     179
#
# Country           Spain  United Kingdom  United States
# SubscriptionType
# Basic               110               3            199
# Premium             212               0            145
# Standard            129             180            107

# %%
# Create a frequency table
frequency_table = pd.crosstab(Data['SubscriptionType'], Data['Country'])

# Create a heatmap for better visualization
plt.figure(figsize=(12, 8))
sns.heatmap(frequency_table, cmap='YlGnBu', annot=True, fmt='g', cbar=False)
plt.title('Subscription Type vs. Country Frequency')
plt.xlabel('Country')
plt.ylabel('Subscription Type')

# Display the heatmap
plt.show()

# %%
# Create a frequency table
frequency_table = pd.crosstab(Data['SubscriptionType'], Data['Country'])

# Set up the plot
plt.figure(figsize=(14, 8))
sns.set(style="whitegrid")

# Create a bar plot for each Subscription Type
for subscription_type in frequency_table.index:
    sns.barplot(x=frequency_table.columns, y=frequency_table.loc[subscription_type], label=subscription_type)

# Set labels and title
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.title('Subscription Type Distribution Across Countries')
plt.legend(title='Subscription Type')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %%
import seaborn as sns
grouped_data = Data.groupby(['Country', 'SubscriptionType']).size().reset_index(name='count')
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='count', hue='SubscriptionType', data=grouped_data)
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Subscription Distribution by Country')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Visualize the relationship using a heatmap or a clustered bar chart to highlight patterns in the data

# %%
# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(frequency_table, cmap='YlGnBu', annot=True, fmt='d', cbar=False)
plt.title('SubscriptionType vs. Country')
plt.show()

# %%
# Heatmap shows United Kingdom has Highest No of Standard Subscription Type user
# Spain has Highest No of Premiun Subscription Type user
# United States Has Hignest No Of Basic Subscription Type User

# %% [markdown]
# What is the relationship between 'Device' and 'MonthlyRevenue'?
#
# Explore whether the device used by subscribers affects their monthly spending.

# %%
# Create a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=Data, x='Device', y='MonthlyRevenue')
plt.title('Box Plot of MonthlyRevenue by Device')
plt.xlabel('Device')
plt.ylabel('MonthlyRevenue')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate summary statistics for 'MonthlyRevenue' by 'Device'
device_summary = Data.groupby('Device')['MonthlyRevenue'].agg(['mean', 'median', 'std']).reset_index()

# Find the device with the highest mean monthly revenue
highest_mean_revenue_device = device_summary.loc[device_summary['mean'].idxmax()]

# Find the device with the highest median monthly revenue
highest_median_revenue_device = device_summary.loc[device_summary['median'].idxmax()]

print("Device with Highest Mean Monthly Revenue:")
print(highest_mean_revenue_device)
print()

print("Device with Highest Median Monthly Revenue:")
print(highest_median_revenue_device)
# Out:
# Device with Highest Mean Monthly Revenue:
# Device       Tablet
# mean      12.592417
# median         13.0
# std        1.703888
# Name: 3, dtype: object
#
# Device with Highest Median Monthly Revenue:
# Device       Laptop
# mean      12.569182
# median         13.0
# std        1.675181
# Name: 0, dtype: object

# %%
# Create a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=Data, x='Device', y='MonthlyRevenue')
plt.title('Bar Chart of Monthly Revenue by Device')
plt.xlabel('Device')
plt.ylabel('Monthly Revenue')
plt.xticks(rotation=45)
plt.show()

# %%
revenue_by_device = Data.groupby('Device')['MonthlyRevenue'].sum()

# Extract labels and values
labels = revenue_by_device.index
values = revenue_by_device.values

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Monthly Revenue by Device')

# Display the pie chart
plt.show()

# %%
country_device = Data.groupby(['Country', 'Device']).size().reset_index(name='count')
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='count', hue='Device', data=country_device)
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Device Distribution by Country')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Analysis Of Age by Plan Duration:

# %%
# Create a grouped bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=Data, x='PlanDuration', y='Age', hue='Age Group')
plt.title('Age by Plan Duration')
plt.xlabel('Plan Duration')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.legend(title='Age Group')

# Display the chart
plt.show()

# %% [markdown]
# # Subscription Duration by Age Group

# %%
# Create a grouped bar chart
plt.figure(figsize=(10, 6))
sns.countplot(data=Data, x='Age Group', hue='Subscription Duration')
plt.title('Subscription Duration by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(title='Subscription Duration')


plt.show()

# %% [markdown]
# Middle Age Group has Highest Subscription Duration

# %%
# Monthly Revenue by Join Year
#To visualize the relationship between monthly revenue and join year,

# %%
# Group the data by 'joinYear' and calculate the total monthly revenue for each year
revenue_by_join_year = Data.groupby('joinYear')['MonthlyRevenue'].sum()

# Create a line chart
plt.figure(figsize=(10, 6))
plt.plot(revenue_by_join_year.index, revenue_by_join_year.values, marker='o', linestyle='-')
plt.title('Monthly Revenue by Join Year')
plt.xlabel('Join Year')
plt.ylabel('Total Monthly Revenue')

# Display the chart
plt.grid(True)
plt.show()

# %% [markdown]
# Line Chart Shows that people Joining in Year(2022) has the Highest month Revenue

# %%
# Relation Between Country and Monthly Revenue

# %%
country_revenue = Data.groupby(['Country'])['MonthlyRevenue'].sum()
print(country_revenue.sort_values(ascending=False))
plt.figure(figsize=(15,6))
plt.bar(country_revenue.index,country_revenue.values,align='center')
# Out:
# Country
# United States     5664
# Spain             5662
# Canada            3950
# United Kingdom    2318
# Italy             2317
# France            2307
# Brazil            2285
# Australia         2271
# Germany           2260
# Mexico            2237
# Name: MonthlyRevenue, dtype: int64
# <BarContainer object of 10 artists>

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# As the name suggests, Multivariate analysis looks at more than two variables. Multivariate analysis is one of the most useful methods to determine relationships
# and manalyze patterns for any dataset.

# %%
Numerical_Variables=['MonthlyRevenue', 'Age', 'joinYear', 'Join Month', 'Join Day','Last Payment Month', 'Last Payment Day']
inp1=Data[Numerical_Variables].copy()

# %%
correlation_matrix = inp1.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.show()

# %%
# 1.	Monthly Revenue Decreases By increasing in Age Group
# 2.	Age And Join Date Has no correlation It means That there is no any relation between Join Date And Age
#3.	Join day and last payment date has Alo no correlation Showing no relation in data

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SubscriptionType       2500 non-null   object
#  1   MonthlyRevenue         2500 non-null   int64
#  2   joinDate               2500 non-null   datetime64[ns]
#  3   LastPaymentDate        2500 non-null   datetime64[ns]
#  4   Country                2500 non-null   object
#  5   Age                    2500 non-null   int64
#  6   Gender                 2500 non-null   int64
#  7   Device                 2500 non-null   object
#  8   PlanDuration           2500 non-null   object
#  9   Subscription Duration  2500 non-null   category
#  10  joinYear               2500 non-null   int32
#  11  Join Month             2500 non-null   int32
#  12  Join Day               2500 non-null   int32
#  13  LastPaymentYear        2500 non-null   int32
#  14  Last Payment Month     2500 non-null   int32
#  15  Last Payment Day       2500 non-null   int32
#  16  Age Group              2500 non-null   category
# dtypes: category(2), datetime64[ns](2), int32(6), int64(3), object(4)
# memory usage: 239.6+ KB

# %% [markdown]
# # Distributions

# %%
for column in num_cols:
    print(column, ':')
    print(Data[column].describe())

# %% [markdown]
# PDF OF Monthly income

# %%
mean = 12.5
std_dev = 1.6
x = np.linspace(5, 20, 10)
pdf = norm.pdf(x, mean, std_dev)

plt.plot(x, pdf)
plt.title("PDF of Monthly Revenue")
plt.xlabel("X")
plt.ylabel("PDF")
plt.show()

# %% [markdown]
#  As you can see The majority of income values cluster
#  around the mean (average) income, which is at the center of the curve.

# %% [markdown]
# PDF OF Age Group

# %%
mean =38.7
std_dev = 7.1
x = np.linspace(20, 55,8)
pdf = norm.pdf(x, mean, std_dev)

plt.plot(x, pdf)
plt.title("PDF of a Standard Normal Distribution")
plt.xlabel("X")
plt.ylabel("PDF")
plt.show()

# %% [markdown]
#  As you can see the mean lies at 40 which indicates majority of customer are middle aged

# %% [markdown]
# PDF of joinYear

# %%
mean =2022.0
std_dev = 0.14
x = np.linspace(2021, 2023,5)
pdf = norm.pdf(x, mean, std_dev)

plt.plot(x, pdf)
plt.title("PDF of a Standard Normal Distribution")
plt.xlabel("Join year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# As we can see there is a slight increase in number of customer between the year 2021 and 2022

# %% [markdown]
# Pdf of Join month

# %%
mean =8.32
std_dev = 1.96
x = np.linspace(1, 12,12)
pdf = norm.pdf(x, mean, std_dev)

plt.plot(x, pdf)
plt.title("PDF of a Standard Normal Distribution")
plt.xlabel("Join month")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# As we can see we have More no of Subscriber In month of June to december it is left Skwed

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# Null Hypothesis (H0):
# The monthly revenue is the same for all subscription types. In other words, there is no significant difference in monthly revenue between subscription types.
#
# Alternative Hypothesis (H1):
# The monthly revenue is not the same for all subscription types. There is a significant difference in monthly revenue between at least two subscription types. write a t test using python

# %%
# Select two subscription types for comparison (e.g., Basic and Premium)
subscription_type_1 = 'Basic'
subscription_type_2 = 'Premium'

# Filter data for the selected subscription types
data_1 = Data[Data['SubscriptionType'] == subscription_type_1]['MonthlyRevenue']
data_2 = Data[Data['SubscriptionType'] == subscription_type_2]['MonthlyRevenue']

# Perform an independent t-test
t_stat, p_value = stats.ttest_ind(data_1, data_2)  # Use stats.ttest_ind, not norm.ttest_ind

# Define your significance level (alpha)
alpha = 0.05

# Compare the p-value to alpha to make a decision
if p_value < alpha:
    print(f"Reject the null hypothesis (H0). There is a significant difference in monthly revenue between {subscription_type_1} and {subscription_type_2}.")
else:
    print(f"Fail to reject the null hypothesis (H0). There is no significant difference in monthly revenue between {subscription_type_1} and {subscription_type_2}.")

# Output the t-statistic and p-value
print(f"t-statistic: {t_stat}")
print(f"p-value: {p_value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 10
#       7 data_2 = Data[Data['SubscriptionType'] == subscription_type_2]['MonthlyRevenue']
#       9 # Perform an independent t-test
# ---> 10 t_stat, p_value = stats.ttest_ind(data_1, data_2)  # Use stats.ttest_ind, not norm.ttest_ind
#      12 # Define your significance level (alpha)
#      13 alpha = 0.05
#
# NameError: name 'stats' is not defined

# %%
# Select numerical columns
numerical_columns = ['MonthlyRevenue', 'Age']

# Create a correlation matrix
correlation_matrix = Data[numerical_columns].corr()

# Generate a heatmap with annotations
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Set the plot title
plt.title('Correlation Matrix for MonthlyRevenue and Age')

# Display the heatmap
plt.show()
